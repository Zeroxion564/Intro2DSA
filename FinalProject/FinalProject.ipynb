# %%
# %matplotlib inline
import numpy as np
import pandas as pnd
import matplotlib as plt
import seaborn as sns; sns.set()

sns.set(style="darkgrid")

# %% [markdown]
# Data Set 1 Link: https://data.ny.gov/Government-Finance/Total-Income-And-Tax-Liability-By-Place-Of-Residen/nacg-rg66

# %%
df1 = pnd.read_csv("NYTaxes.csv")
display(df1)
# Out:
#       Tax Year          Resident Type                  Place of Residence  \
# 0         2011     Full-Year Resident               New York City - Bronx
# 1         2011     Full-Year Resident               New York City - Kings
# 2         2011     Full-Year Resident           New York City - Manhattan
# 3         2011     Full-Year Resident              New York City - Queens
# 4         2011     Full-Year Resident            New York City - Richmond
# 5         2011     Full-Year Resident                Total, New York City
# 6         2011     Full-Year Resident                              Albany
# 7         2011     Full-Year Resident                            Allegany
# 8         2011     Full-Year Resident                              Broome
# 9         2011     Full-Year Resident                         Cattaraugus
# 10        2011     Full-Year Resident                              Cayuga
# 11        2011     Full-Year Resident                          Chautauqua
# ...

# %%
df1.shape
# Out:
# (1864, 22)

# %%
df1.dtypes
# Out:
# Tax Year                                                   int64
# Resident Type                                             object
# Place of Residence                                        object
# Country                                                   object
# State                                                     object
# County                                                    object
# Disclosure                                               float64
# Number of All Returns                                     object
# NY AGI of All Returns (in thousands) *                    object
# Tax Liability of All Returns (in thousands) **            object
# Number of Taxable Returns                                 object
# NY AGI of Taxable Returns (in thousands) *                object
# Tax Liability of Taxable Returns (in thousands) **        object
# Number of Nontaxable Returns                              object
# ...

# %%
df1.describe()
# Out:
#           Tax Year  Disclosure  County Sort Order
# count  1864.000000         0.0        1864.000000
# mean   2006.901288         NaN          82.333155
# std       4.662860         NaN          64.878648
# min    1999.000000         NaN           1.000000
# 25%    2003.000000         NaN          30.000000
# 50%    2007.000000         NaN          59.000000
# 75%    2011.000000         NaN         128.000000
# max    2014.000000         NaN         299.000000

# %% [markdown]
# Data Set 2 Link: https://data.ny.gov/Government-Finance/Income-Tax-Components-by-Size-of-Income-by-Place-o/5bb2-yb85

# %%
df2 = pnd.read_csv("PersonalIncomeBrackets.csv")
df2
# Out:
#        Tax Year          Resident Type                  Place of Residence  \
# 0          2012  Full-Year Nonresident                             Ireland
# 1          2012  Full-Year Nonresident                             Ireland
# 2          2012  Full-Year Nonresident                             Ireland
# 3          2012  Full-Year Nonresident                        A.P.O./F.P.O
# 4          2012  Full-Year Nonresident                        A.P.O./F.P.O
# 5          2012  Full-Year Nonresident                        A.P.O./F.P.O
# 6          2012  Full-Year Nonresident                        A.P.O./F.P.O
# 7          2012  Full-Year Nonresident                        A.P.O./F.P.O
# 8          2012  Full-Year Nonresident                        A.P.O./F.P.O
# 9          2012  Full-Year Nonresident                        A.P.O./F.P.O
# 10         2012  Full-Year Nonresident                        A.P.O./F.P.O
# ...

# %%
df2.shape
# Out:
# (23735, 17)

# %%
df2.dtypes
# Out:
# Tax Year                                               int64
# Resident Type                                         object
# Place of Residence                                    object
# Country                                               object
# State                                                 object
# County                                                object
# Income Class                                          object
# Disclosure                                            object
# Number of All Returns                                 object
# NY AGI of All Returns (in thousands) *                object
# Deductions of All Returns (in thousands)              object
# Dependent Exemptions of All Returns (in thousands)    object
# Taxable Income of All Returns (in thousands)          object
# Tax Before Credits of All Returns (in thousands)      object
# Tax Liability of All Returns (in thousands) **        object
# ...

# %%
df2.describe()
# Out:
#            Tax Year  Place of Residence Sort Order  Income Class Sort Order
# count  23735.000000                   23735.000000             23735.000000
# mean    2007.220645                      81.604803                 7.073773
# std        4.632102                      62.110581                 3.827778
# min     1999.000000                       1.000000                 1.000000
# 25%     2003.000000                      30.000000                 4.000000
# 50%     2008.000000                      59.000000                 7.000000
# 75%     2011.000000                     128.000000                10.000000
# max     2014.000000                     250.000000                14.000000
